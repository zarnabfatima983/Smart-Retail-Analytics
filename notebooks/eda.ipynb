# %%
import pandas as pd

df = pd.read_csv(
    "../data/SampleSuperstore.csv",
    encoding='latin1'
)

df.head()
# Out:
#    python -m streamlit run app.pyRow ID        Order ID  Order Date  \
# 0                                     1  CA-2016-152156   11/8/2016
# 1                                     2  CA-2016-152156   11/8/2016
# 2                                     3  CA-2016-138688   6/12/2016
# 3                                     4  US-2015-108966  10/11/2015
# 4                                     5  US-2015-108966  10/11/2015
#
#     Ship Date       Ship Mode Customer ID    Customer Name    Segment  \
# 0  11/11/2016    Second Class    CG-12520      Claire Gute   Consumer
# 1  11/11/2016    Second Class    CG-12520      Claire Gute   Consumer
# 2   6/16/2016    Second Class    DV-13045  Darrin Van Huff  Corporate
# 3  10/18/2015  Standard Class    SO-20335   Sean O'Donnell   Consumer
# 4  10/18/2015  Standard Class    SO-20335   Sean O'Donnell   Consumer
#
#          Country             City  ... Postal Code  Region       Product ID  \
# 0  United States        Henderson  ...       42420   South  FUR-BO-10001798
# 1  United States        Henderson  ...       42420   South  FUR-CH-10000454
# 2  United States      Los Angeles  ...       90036    West  OFF-LA-10000240
# 3  United States  Fort Lauderdale  ...       33311   South  FUR-TA-10000577
# 4  United States  Fort Lauderdale  ...       33311   South  OFF-ST-10000760
#
#           Category Sub-Category  \
# 0        Furniture    Bookcases
# 1        Furniture       Chairs
# 2  Office Supplies       Labels
# 3        Furniture       Tables
# 4  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   python -m streamlit run app.pyRow ID  9994 non-null   int64
#  1   Order ID                              9994 non-null   str
#  2   Order Date                            9994 non-null   str
#  3   Ship Date                             9994 non-null   str
#  4   Ship Mode                             9994 non-null   str
#  5   Customer ID                           9994 non-null   str
#  6   Customer Name                         9994 non-null   str
#  7   Segment                               9994 non-null   str
#  8   Country                               9994 non-null   str
#  9   City                                  9994 non-null   str
#  10  State                                 9994 non-null   str
#  11  Postal Code                           9994 non-null   int64
#  12  Region                                9994 non-null   str
#  13  Product ID                            9994 non-null   str
#  14  Category                              9994 non-null   str
#  15  Sub-Category                          9994 non-null   str
#  16  Product Name                          9994 non-null   str
#  17  Sales                                 9994 non-null   float64
#  18  Quantity                              9994 non-null   int64
#  19  Discount                              9994 non-null   float64
#  20  Profit                                9994 non-null   float64
# dtypes: float64(3), int64(3), str(15)
# memory usage: 3.3 MB

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])

df['Ship Date'] = pd.to_datetime(df['Ship Date'])

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   python -m streamlit run app.pyRow ID  9994 non-null   int64
#  1   Order ID                              9994 non-null   str
#  2   Order Date                            9994 non-null   datetime64[us]
#  3   Ship Date                             9994 non-null   datetime64[us]
#  4   Ship Mode                             9994 non-null   str
#  5   Customer ID                           9994 non-null   str
#  6   Customer Name                         9994 non-null   str
#  7   Segment                               9994 non-null   str
#  8   Country                               9994 non-null   str
#  9   City                                  9994 non-null   str
#  10  State                                 9994 non-null   str
#  11  Postal Code                           9994 non-null   int64
#  12  Region                                9994 non-null   str
#  13  Product ID                            9994 non-null   str
#  14  Category                              9994 non-null   str
#  15  Sub-Category                          9994 non-null   str
#  16  Product Name                          9994 non-null   str
#  17  Sales                                 9994 non-null   float64
#  18  Quantity                              9994 non-null   int64
#  19  Discount                              9994 non-null   float64
#  20  Profit                                9994 non-null   float64
# dtypes: datetime64[us](2), float64(3), int64(3), str(13)
# memory usage: 3.2 MB

# %%
total_sales = df['Sales'].sum()

print("Total Sales:", total_sales)
# Out:
# Total Sales: 2297200.8603

# %%
total_profit = df['Profit'].sum()

print("Total Profit:", total_profit)
# Out:
# Total Profit: 286397.0217

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
category_sales = df.groupby('Category')['Sales'].sum()

category_sales.plot(kind='bar')

plt.title("Sales by Category")

plt.xlabel("Category")

plt.ylabel("Sales")

plt.show()

# %%
category_profit = df.groupby('Category')['Profit'].sum()

category_profit.plot(kind='bar')

plt.title("Profit by Category")

plt.xlabel("Category")

plt.ylabel("Profit")

plt.show()

# %%
df['Year'] = df['Order Date'].dt.year

df['Month'] = df['Order Date'].dt.month

df['Month Name'] = df['Order Date'].dt.month_name()

# %%
month_order = [
    'January', 'February', 'March', 'April',
    'May', 'June', 'July', 'August',
    'September', 'October', 'November', 'December'
]

monthly_sales = df.groupby('Month Name')['Sales'].sum().reindex(month_order)

monthly_sales.plot(kind='line', marker='o')

plt.title("Monthly Sales Trend")

plt.xlabel("Month")

plt.ylabel("Sales")

plt.show()
